# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt
import glob 
import torch
import torchaudio
import torchaudio.transforms as T

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from torch import nn

# to play the audio files
from IPython.display import Audio

# %%
# Base directory
base_dir_tess = "./TESS"

# Lists to store file paths and emotions from the filename
file_paths = []
emotions = []

for emotions_folder in sorted(glob.glob(os.path.join(base_dir_tess, "YAF_*"))):
    wav_files = glob.glob(os.path.join(emotions_folder, "*.wav"))

    for wav_file in wav_files:
        file_paths.append(wav_file)
        
        filename = os.path.basename(wav_file)
        
        # Split by '_' and get the third number
        parts = filename.split('_')
        if len(parts) >= 3:
            emotion = (parts[2])[:-4]
            if emotion == "ps":
                emotions.append("surprised")
            else:
                emotions.append(emotion)
        else:
            print(f"Warning: unexpected filename format: {filename}")

# Check if both lists are equal in length
print(f"Collected {len(file_paths)} files.")
print(f"Collected {len(emotions)} labels.")
print("Example:", file_paths[200], "->", emotions[200])
# Out:
# Collected 2800 files.
# Collected 2800 labels.
# Example: ./TESS\YAF_angry\YAF_back_angry.wav -> angry

# %%
# Base directory
base_dir = "./archive"

# Lists to store file paths and emotions from the filename
#file_paths = []
#emotions = []

emotions_dict ={
    "01" : "neutral",
    "02" : "calm",
    "03" : "happy",
    "04" : "sad",
    "05" : "angry",
    "06" : "fear",
    "07" : "disgust",
    "08" : "surprised"
}

# Loop over all Actor_XX folders
for actor_folder in sorted(glob.glob(os.path.join(base_dir, "Actor_*"))):
    wav_files = glob.glob(os.path.join(actor_folder, "*.wav"))
    
    for wav_file in wav_files:
        # Append full path to the list
        file_paths.append(wav_file)
        
        # Extract filename (without folder)
        filename = os.path.basename(wav_file)
        
        # Split by '-' and get the third number
        parts = filename.split('-')
        if len(parts) >= 3:
            emotion_number = parts[2]
            emotions.append(emotions_dict[emotion_number])
        else:
            print(f"Warning: unexpected filename format: {filename}")

# Check if both lists are equal in length
print(f"Collected {len(file_paths)} files.")
print(f"Collected {len(emotions)} labels.")
print("Example:", file_paths[3000], "->", emotions[3000])
# Out:
# Collected 4240 files.
# Collected 4240 labels.
# Example: ./archive\Actor_04\03-01-04-01-01-01-04.wav -> sad

# %%
x_train_paths, x_temp_paths, y_train_emotions, y_temp = train_test_split(
    file_paths, emotions, test_size=0.3, random_state=45, shuffle=True
)

x_val_paths, x_test_paths, y_val_emotions, y_test_emotions = train_test_split(
    x_temp_paths, y_temp, test_size=0.5, random_state=45, shuffle=True
)

print(len(x_train_paths), len(x_val_paths), len(x_test_paths))
print(len(y_train_emotions), len(y_val_emotions), len(y_test_emotions))
# Out:
# 2968 636 636
# 2968 636 636

# %% [markdown]
# ### Plotting Functions

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(15, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

def plot_loss_acc(train_losses, train_accs, val_losses, val_accs, plot_name):
    plt.figure(figsize=(12,5))

    # Loss
    plt.subplot(1,2,1)
    plt.plot(train_losses, label="Train Loss")
    plt.plot(val_losses, label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss over epochs")

    # Accuracy
    plt.subplot(1,2,2)
    plt.plot(train_accs, label="Train Acc")
    plt.plot(val_accs, label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.title("Accuracy over epochs")

    plt.tight_layout()
    plt.savefig(plot_name + ".jpg", dpi=500)
    plt.show()

# %%
# %matplotlib inline

path = "./archive/Actor_01/03-01-06-01-02-01-01.wav"

data, sampling_rate = librosa.load(path)

create_waveplot(data, sampling_rate, 'fear')
create_spectrogram(data, sampling_rate, 'fear')

Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Augmentation

# %%
def noise(waveform, noise_factor=0.05):
    """
    Adds Gaussian noise to a waveform tensor.
    waveform: torch.Tensor (1, num_samples)
    """
    noise = torch.randn_like(waveform)
    augmented = waveform + noise_factor * noise * waveform.abs().max()
    return augmented.clamp(-1.0, 1.0)

def shift(waveform, sampling_rate, n_steps=2):
    """
    Shifts pitch by n_steps semitones without changing duration.
    """
    transform = T.PitchShift(sample_rate=sampling_rate, n_steps=n_steps)
    return transform(waveform)

# %%
def extract_melspectrogram(waveform, sampling_rate):
    """
    Computes mean Mel-spectrogram features for a waveform tensor.
    Returns a 1D NumPy array.
    """
    mel_transform = T.MelSpectrogram(
        sample_rate=sampling_rate,
        n_mels=128,
        n_fft=2048,
        hop_length=512
    )
    mel_spec = mel_transform(waveform)                # shape: (1, n_mels, time)
    mel_db = T.AmplitudeToDB()(mel_spec)              # convert to dB scale
    #mel_mean = torch.mean(mel_db, dim=-1).squeeze(0)  # average across time - not used anymore since we need time dimension for gru
    #return mel_mean.detach().numpy()                  # return as NumPy array
    return mel_db.squeeze(0).detach().numpy()

def get_feature(path, data_origin, augment, duration=3, offset=0.5):
    """
    Loads an audio file, extracts features with and without augmentations.
    Returns a 2D NumPy array: [original, pitch-shifted, noise-augmented].
    """
    # Load audio
    data, sr = librosa.load(path)
    waveform = torch.tensor(data, dtype=torch.float32).unsqueeze(0)
    target_len = int(sr * duration)
    
    if data_origin.upper() == "RAVDESS":
        # Clip starting from offset
        start = int(offset * sr)
        end = start + target_len
        waveform = waveform[:, start:end]

        # If shorter, pad at the end
        if waveform.shape[1] < target_len:
            pad_len = target_len - waveform.shape[1]
            waveform = torch.nn.functional.pad(waveform, (0, pad_len))

    elif data_origin.upper() == "TESS":
        cur_len = waveform.shape[1]
        if cur_len < target_len:
            pad_total = target_len - cur_len
            pad_start = pad_total // 2
            pad_end = pad_total - pad_start
            waveform = torch.nn.functional.pad(waveform, (pad_start, pad_end))
        else:
            # we should not get here
            print("A clip in TESS is of weird length")
            start = (cur_len - target_len) // 2
            waveform = waveform[:, start:start + target_len]

    # pad with zeros
    if waveform.shape[1] < target_len:
        pad_len = target_len - waveform.shape[1]
        waveform = torch.nn.functional.pad(waveform, (0, pad_len))

    # no augmentation
    base_features = extract_melspectrogram(waveform, sr)       # (128, time)
    result = np.expand_dims(base_features, axis=0)            # (1, 128, time)

    if augment:
        # pitch-shifting
        pitched = shift(waveform, sr, n_steps=2)
        pitched_features = extract_melspectrogram(pitched, sr)
        result = np.vstack((result, np.expand_dims(pitched_features, axis=0)))
    
        # noise-augmentation
        noised = noise(waveform, noise_factor=0.05)
        noised_features = extract_melspectrogram(noised, sr)
        result = np.vstack((result, np.expand_dims(noised_features, axis=0)))

    return result

def extract_dataset_features(file_paths, emotions, augment):
    audio_files_features, corresponding_emotions = [], []
    
    for path, emotion in zip(file_paths, emotions):
        # Detect dataset origin
        if path.startswith("./archive"):
            origin = "RAVDESS"
        elif path.startswith("./TESS"):
            origin = "TESS"
        else:
            print("WRONG FILENAME FORMAT")
            continue
        
        feature = get_feature(path, origin, augment)
        
        # if augment=True, get_feature returns multiple variants vertically stacked (base, pitch, noise), otherwise only oringial's features
        for audio_file in feature:
            audio_files_features.append(audio_file)
            corresponding_emotions.append(emotion)
    
    return np.array(audio_files_features), np.array(corresponding_emotions)

# %% [markdown]
# ## Mel-Spectrogram features

# %% [markdown]
# ### Recreating the features from scratch

# %%
"""
# train is the only set augmented
x_train_features, y_train_corresponding_emotions = extract_dataset_features(x_train_paths, y_train_emotions, True)

# validation & test without augmentation
x_val_features, y_val_corresponding_emotions = extract_dataset_features(x_val_paths, y_val_emotions, False)
x_test_features, y_test_corresponding_emotions = extract_dataset_features(x_test_paths, y_test_emotions, False)

print(len(x_train_features), len(y_train_corresponding_emotions))
print(len(x_val_features), len(y_val_corresponding_emotions))
print(len(x_test_features), len(y_test_corresponding_emotions))
"""
# Out:
# 8904 8904
# 636 636
# 636 636

# %% [markdown]
# ### Loading existing features from checkpoint

# %%
checkpoint = torch.load("features_split_2d.ckpt", weights_only=False)
x_train_features, y_train_corresponding_emotions = checkpoint["x_train_features"], checkpoint["y_train_corresponding_emotions"]
x_val_features, y_val_corresponding_emotions = checkpoint["x_val_features"], checkpoint["y_val_corresponding_emotions"]
x_test_features, y_test_corresponding_emotions = checkpoint["x_test_features"], checkpoint["y_test_corresponding_emotions"]

print(len(x_train_features), len(y_train_corresponding_emotions))
print(len(x_val_features), len(y_val_corresponding_emotions))
print(len(x_test_features), len(y_test_corresponding_emotions))
# Out:
# 8904 8904
# 636 636
# 636 636

# %% [markdown]
# ### Saving features

# %%
# Should not be ran anymore since we have a checkpoint of the features used in the final results
"""
torch.save(
    {
        "x_train_features": x_train_features,
        "x_val_features": x_val_features,
        "x_test_features": x_test_features,
        "y_train_corresponding_emotions": y_train_corresponding_emotions,
        "y_val_corresponding_emotions": y_val_corresponding_emotions,
        "y_test_corresponding_emotions": y_test_corresponding_emotions,
    },
    "./features_split_2d.ckpt",
)
"""

# %%
#df = pd.DataFrame(audio_files_features)
#df['emotions'] = corresponding_emotions
#df.tail()

# %%
print(len(x_train_features[0]))
# Out:
# 128

# %%
# one hot encoding of emotions
encoder = OneHotEncoder()
y_train = encoder.fit_transform(y_train_corresponding_emotions.reshape(-1, 1)).toarray()
y_val   = encoder.transform(y_val_corresponding_emotions.reshape(-1, 1)).toarray()
y_test  = encoder.transform(y_test_corresponding_emotions.reshape(-1, 1)).toarray()

# change from one hot encoding to class indices
y_train = np.argmax(y_train, axis=1)
y_val = np.argmax(y_val, axis=1)
y_test = np.argmax(y_test, axis=1)

# We are aware that the two steps above are redundant since does the one hot encoding and one reverts that to class indices, but this is how it evolved

x_train = np.expand_dims(x_train_features, axis=1)
x_val   = np.expand_dims(x_val_features, axis=1)
x_test  = np.expand_dims(x_test_features, axis=1)

x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((8904, 1, 128, 130),
#  (8904,),
#  (636, 1, 128, 130),
#  (636,),
#  (636, 1, 128, 130),
#  (636,))

# %% [markdown]
# # CNN

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 16, 3),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.2),
            nn.Conv2d(16, 32, 3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, 3),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.AdaptiveAvgPool2d((4, 4)),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, 1, 128, 130) #(batch, channel, frequency, time)
            out = self.cnn(dummy)
            n_flatten = out.view(1, -1).size(1)

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(n_flatten, 8)
            # no activation since we use CrossEntropyLoss
        )
    def forward(self, input_batch):
        output = self.cnn(input_batch)
        output = self.classifier(output)         
        return output

# %% [markdown]
# # CNN-GRU

# %%
class CNN_GRU(nn.Module):
    def __init__(self):
        super(CNN_GRU, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 32, 3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.2),
            nn.Conv2d(32, 64, 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, 3),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(128, 256, 3),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(p=0.3),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, 1, 128, 130) #(batch, channel, frequency, time)
            out = self.cnn(dummy) #(batch, channel, frequency, time)
            B, C, F, T = out.shape
            gru_input_size = C * F

        self.gru = nn.GRU(input_size=gru_input_size, hidden_size=128, num_layers=2, batch_first=True, bidirectional=True)

        self.drop = nn.Dropout(p=0.3)
        
        self.classifier = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 8)
            # no activation since we use CrossEntropyLoss
        )
    def forward(self, input_batch):
        output = self.cnn(input_batch) #B, C, F, T
        output = output.permute(0, 3, 1, 2) #B, T, C, F
        batch, time, channels, frequency = output.shape
        output = output.reshape(batch, time, channels*frequency)
        output, _ = self.gru(output)
        output = self.drop(output)
        output = output[:, -1, :]            
        output = self.classifier(output)         
        return output

# %%
def training_loop(
    model, optimizer, loss_fn, train_loader, val_loader, num_epochs, print_every, scheduler
):
    print("Starting training")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    train_losses, train_accs, val_losses, val_accs = [], [], [], []

    for epoch in range(1, num_epochs + 1):
        model, train_loss, train_acc = train_epoch(
            model, optimizer, loss_fn, train_loader, val_loader, device, print_every
        )
        val_loss, val_acc = validate(model, loss_fn, val_loader, device)
        scheduler.step(val_loss) #scheduler step with val_loss for the patience attribute to be applied
        print(
            f"Epoch {epoch}/{num_epochs}: "
            f"Train loss: {sum(train_loss)/len(train_loss):.3f}, "
            f"Train acc.: {sum(train_acc)/len(train_acc):.3f}, "
            f"Val. loss: {val_loss:.3f}, "
            f"Val. acc.: {val_acc:.3f}"
        )
        #train_losses.extend(train_loss)
        #train_accs.extend(train_acc)
        train_losses.append((sum(train_loss) / len(train_loss)))
        train_accs.append((sum(train_acc)/len(train_acc)))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
    return model, train_losses, train_accs, val_losses, val_accs


def train_epoch(
    model, optimizer, loss_fn, train_loader, val_loader, device, print_every
):
    # Train:
    model.train()
    train_loss_batches, train_acc_batches = [], []
    num_batches = len(train_loader)
    for batch_index, (x, y) in enumerate(train_loader, 1):
        inputs, labels = x.to(device), y.to(device)
        optimizer.zero_grad()
        z = model.forward(inputs)
        loss = loss_fn(z, labels.long())
        loss.backward()
        optimizer.step()
        train_loss_batches.append(loss.item())

        hard_preds = torch.argmax(z, dim=1)
        acc_batch_avg = (hard_preds == labels).float().mean().item()
        train_acc_batches.append(acc_batch_avg)

        # If you want to print your progress more often than every epoch you can
        # set `print_every` to the number of batches you want between every status update.
        # Note that the print out will trigger a full validation on the full val. set => slows down training
        if print_every is not None and batch_index % print_every == 0:
            val_loss, val_acc = validate(model, loss_fn, val_loader, device)
            model.train()
            print(
                f"\tBatch {batch_index}/{num_batches}: "
                f"\tTrain loss: {sum(train_loss_batches[-print_every:])/print_every:.3f}, "
                f"\tTrain acc.: {sum(train_acc_batches[-print_every:])/print_every:.3f}, "
                f"\tVal. loss: {val_loss:.3f}, "
                f"\tVal. acc.: {val_acc:.3f}"
            )
    
    return model, train_loss_batches, train_acc_batches


def validate(model, loss_fn, val_loader, device):
    val_loss_cum = 0
    val_acc_cum = 0
    model.eval()
    with torch.no_grad():
        for batch_index, (x, y) in enumerate(val_loader, 1):
            inputs, labels = x.to(device), y.to(device)
            z = model.forward(inputs)

            batch_loss = loss_fn(z, labels.long())
            val_loss_cum += batch_loss.item()
            hard_preds = torch.argmax(z, dim=1)
            acc_batch_avg = (hard_preds == labels).float().mean().item()
            val_acc_cum += acc_batch_avg
    return val_loss_cum / len(val_loader), val_acc_cum / len(val_loader)

# %%
from torch.utils.data import Dataset, DataLoader

class AudioFeatureDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
""" recreating weights """
#emotion_counts = df['emotions'].value_counts().sort_index()
#from collections import Counter
#emotion_counts = Counter(emotions)
#emotion_counts = dict(sorted(emotion_counts.items()))
#counts = torch.tensor(list(emotion_counts.values()), dtype=torch.float32)
#w = 1.0 / counts
#w = w / w.sum()

""" Loading existing weights """
w = torch.load("weights.ckpt")["weights"]

print(w)
# Out:
# tensor([0.0973, 0.3000, 0.0973, 0.0973, 0.0973, 0.1161, 0.0973, 0.0973])

# %%
torch.save(
    {
        "weights": w
    },
    "./weights.ckpt",
)

# %% [markdown]
# ## CNN

# %% [markdown]
# ### Loading existing model

# %%
#trained_model_cnn = CNN() # Saved the wrong model called "model" instead of "trained_model_cnn" so model is lost but accs and losses are saved
checkpoint = torch.load("cnn_model_2d_checkpoint.ckpt")
#trained_model.load_state_dict(checkpoint["model_state_dict"])
train_losses_cnn, train_accs_cnn = checkpoint["train_losses_cnn"], checkpoint["train_accs_cnn"] 
val_losses_cnn, val_accs_cnn = checkpoint["val_losses_cnn"], checkpoint["val_accs_cnn"]

# %% [markdown]
# ### Creating a new model

# %%
batch_size = 128
epochs = 70
prints = 71
learning_rate = 1e-5
weight_decay = 1e-4

train_dataset = AudioFeatureDataset(x_train, y_train)
val_dataset = AudioFeatureDataset(x_val, y_val)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

#model = CNN()

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.8)


#trained_model_cnn, train_losses_cnn, train_accs_cnn, val_losses_cnn, val_accs_cnn = training_loop(
#    model, optimizer, loss_fn, train_dataloader, val_dataloader, epochs, prints, scheduler
#)
# Out:
# Starting training
# Epoch 1/70: Train loss: 1.971, Train acc.: 0.228, Val. loss: 1.890, Val. acc.: 0.253
# Epoch 2/70: Train loss: 1.779, Train acc.: 0.363, Val. loss: 1.777, Val. acc.: 0.352
# Epoch 3/70: Train loss: 1.655, Train acc.: 0.442, Val. loss: 1.695, Val. acc.: 0.439
# Epoch 4/70: Train loss: 1.556, Train acc.: 0.495, Val. loss: 1.628, Val. acc.: 0.473
# Epoch 5/70: Train loss: 1.474, Train acc.: 0.529, Val. loss: 1.554, Val. acc.: 0.489
# Epoch 6/70: Train loss: 1.401, Train acc.: 0.563, Val. loss: 1.483, Val. acc.: 0.527
# Epoch 7/70: Train loss: 1.335, Train acc.: 0.591, Val. loss: 1.435, Val. acc.: 0.542
# Epoch 8/70: Train loss: 1.280, Train acc.: 0.613, Val. loss: 1.377, Val. acc.: 0.556
# Epoch 9/70: Train loss: 1.231, Train acc.: 0.634, Val. loss: 1.331, Val. acc.: 0.580
# Epoch 10/70: Train loss: 1.186, Train acc.: 0.645, Val. loss: 1.285, Val. acc.: 0.608
# Epoch 11/70: Train loss: 1.148, Train acc.: 0.661, Val. loss: 1.240, Val. acc.: 0.621
# Epoch 12/70: Train loss: 1.112, Train acc.: 0.674, Val. loss: 1.190, Val. acc.: 0.649
# Epoch 13/70: Train loss: 1.081, Train acc.: 0.674, Val. loss: 1.162, Val. acc.: 0.653
# Epoch 14/70: Train loss: 1.051, Train acc.: 0.688, Val. loss: 1.127, Val. acc.: 0.664
# Epoch 15/70: Train loss: 1.026, Train acc.: 0.693, Val. loss: 1.114, Val. acc.: 0.662
# Epoch 16/70: Train loss: 0.999, Train acc.: 0.702, Val. loss: 1.084, Val. acc.: 0.675
# Epoch 17/70: Train loss: 0.974, Train acc.: 0.705, Val. loss: 1.052, Val. acc.: 0.687
# Epoch 18/70: Train loss: 0.954, Train acc.: 0.713, Val. loss: 1.038, Val. acc.: 0.690
# Epoch 19/70: Train loss: 0.933, Train acc.: 0.719, Val. loss: 1.002, Val. acc.: 0.703
# Epoch 20/70: Train loss: 0.915, Train acc.: 0.726, Val. loss: 0.987, Val. acc.: 0.700
# Epoch 21/70: Train loss: 0.893, Train acc.: 0.727, Val. loss: 0.968, Val. acc.: 0.711
# Epoch 22/70: Train loss: 0.877, Train acc.: 0.734, Val. loss: 0.946, Val. acc.: 0.711
# Epoch 23/70: Train loss: 0.860, Train acc.: 0.734, Val. loss: 0.931, Val. acc.: 0.714
# Epoch 24/70: Train loss: 0.842, Train acc.: 0.746, Val. loss: 0.914, Val. acc.: 0.722
# Epoch 25/70: Train loss: 0.827, Train acc.: 0.745, Val. loss: 0.893, Val. acc.: 0.726
# Epoch 26/70: Train loss: 0.810, Train acc.: 0.755, Val. loss: 0.873, Val. acc.: 0.731
# Epoch 27/70: Train loss: 0.799, Train acc.: 0.756, Val. loss: 0.879, Val. acc.: 0.736
# Epoch 28/70: Train loss: 0.785, Train acc.: 0.762, Val. loss: 0.866, Val. acc.: 0.737
# Epoch 29/70: Train loss: 0.771, Train acc.: 0.767, Val. loss: 0.828, Val. acc.: 0.741
# Epoch 30/70: Train loss: 0.759, Train acc.: 0.772, Val. loss: 0.834, Val. acc.: 0.737
# Epoch 31/70: Train loss: 0.747, Train acc.: 0.772, Val. loss: 0.827, Val. acc.: 0.734
# Epoch 32/70: Train loss: 0.734, Train acc.: 0.772, Val. loss: 0.792, Val. acc.: 0.747
# Epoch 33/70: Train loss: 0.726, Train acc.: 0.778, Val. loss: 0.806, Val. acc.: 0.748
# Epoch 34/70: Train loss: 0.714, Train acc.: 0.781, Val. loss: 0.790, Val. acc.: 0.751
# Epoch 35/70: Train loss: 0.704, Train acc.: 0.786, Val. loss: 0.778, Val. acc.: 0.753
# Epoch 36/70: Train loss: 0.692, Train acc.: 0.787, Val. loss: 0.783, Val. acc.: 0.745
# Epoch 37/70: Train loss: 0.682, Train acc.: 0.790, Val. loss: 0.764, Val. acc.: 0.744
# Epoch 38/70: Train loss: 0.675, Train acc.: 0.793, Val. loss: 0.764, Val. acc.: 0.753
# Epoch 39/70: Train loss: 0.668, Train acc.: 0.795, Val. loss: 0.756, Val. acc.: 0.751
# Epoch 40/70: Train loss: 0.659, Train acc.: 0.798, Val. loss: 0.746, Val. acc.: 0.756
# Epoch 41/70: Train loss: 0.653, Train acc.: 0.801, Val. loss: 0.747, Val. acc.: 0.759
# Epoch 42/70: Train loss: 0.644, Train acc.: 0.802, Val. loss: 0.740, Val. acc.: 0.756
# Epoch 43/70: Train loss: 0.634, Train acc.: 0.807, Val. loss: 0.730, Val. acc.: 0.759
# Epoch 44/70: Train loss: 0.629, Train acc.: 0.806, Val. loss: 0.731, Val. acc.: 0.762
# Epoch 45/70: Train loss: 0.621, Train acc.: 0.810, Val. loss: 0.727, Val. acc.: 0.762
# Epoch 46/70: Train loss: 0.619, Train acc.: 0.811, Val. loss: 0.712, Val. acc.: 0.766
# Epoch 47/70: Train loss: 0.610, Train acc.: 0.812, Val. loss: 0.697, Val. acc.: 0.769
# Epoch 48/70: Train loss: 0.606, Train acc.: 0.815, Val. loss: 0.709, Val. acc.: 0.767
# Epoch 49/70: Train loss: 0.600, Train acc.: 0.813, Val. loss: 0.698, Val. acc.: 0.767
# Epoch 50/70: Train loss: 0.591, Train acc.: 0.815, Val. loss: 0.696, Val. acc.: 0.769
# Epoch 51/70: Train loss: 0.590, Train acc.: 0.812, Val. loss: 0.689, Val. acc.: 0.767
# Epoch 52/70: Train loss: 0.583, Train acc.: 0.817, Val. loss: 0.690, Val. acc.: 0.767
# Epoch 53/70: Train loss: 0.577, Train acc.: 0.822, Val. loss: 0.695, Val. acc.: 0.770
# Epoch 54/70: Train loss: 0.571, Train acc.: 0.824, Val. loss: 0.682, Val. acc.: 0.770
# Epoch 55/70: Train loss: 0.566, Train acc.: 0.820, Val. loss: 0.680, Val. acc.: 0.769
# Epoch 56/70: Train loss: 0.566, Train acc.: 0.821, Val. loss: 0.668, Val. acc.: 0.773
# Epoch 57/70: Train loss: 0.557, Train acc.: 0.827, Val. loss: 0.656, Val. acc.: 0.778
# Epoch 58/70: Train loss: 0.553, Train acc.: 0.827, Val. loss: 0.669, Val. acc.: 0.777
# Epoch 59/70: Train loss: 0.551, Train acc.: 0.826, Val. loss: 0.664, Val. acc.: 0.777
# Epoch 60/70: Train loss: 0.543, Train acc.: 0.825, Val. loss: 0.652, Val. acc.: 0.778
# Epoch 61/70: Train loss: 0.539, Train acc.: 0.827, Val. loss: 0.638, Val. acc.: 0.777
# Epoch 62/70: Train loss: 0.537, Train acc.: 0.826, Val. loss: 0.647, Val. acc.: 0.778
# Epoch 63/70: Train loss: 0.531, Train acc.: 0.831, Val. loss: 0.633, Val. acc.: 0.778
# Epoch 64/70: Train loss: 0.526, Train acc.: 0.831, Val. loss: 0.644, Val. acc.: 0.777
# Epoch 65/70: Train loss: 0.525, Train acc.: 0.830, Val. loss: 0.630, Val. acc.: 0.780
# Epoch 66/70: Train loss: 0.520, Train acc.: 0.836, Val. loss: 0.627, Val. acc.: 0.784
# Epoch 67/70: Train loss: 0.519, Train acc.: 0.832, Val. loss: 0.631, Val. acc.: 0.787
# Epoch 68/70: Train loss: 0.515, Train acc.: 0.834, Val. loss: 0.636, Val. acc.: 0.781
# Epoch 69/70: Train loss: 0.509, Train acc.: 0.839, Val. loss: 0.623, Val. acc.: 0.784
# Epoch 70/70: Train loss: 0.506, Train acc.: 0.837, Val. loss: 0.623, Val. acc.: 0.786

# %%
plot_loss_acc(train_losses_cnn, train_accs_cnn, val_losses_cnn, val_accs_cnn, "cnn_model_2D_stable")

# %% [markdown]
# ### Saving CNN

# %%
# Should not be ran anymore since we got the final results
"""
torch.save(
    {
        "model_state_dict": model.state_dict(), # Saved the wrong model for CNN
        "train_losses_cnn": train_losses_cnn, 
        "train_accs_cnn": train_accs_cnn, 
        "val_losses_cnn": val_losses_cnn, 
        "val_accs_cnn": val_accs_cnn
    },
    "./cnn_model_2d_checkpoint.ckpt",
)
"""

# %% [markdown]
# ## CNN_GRU

# %% [markdown]
# ### Loading existing model

# %%
trained_model = CNN_GRU()
checkpoint = torch.load("cnn_gru_model_2d_stable.ckpt")
trained_model.load_state_dict(checkpoint["model_state_dict"])
train_losses, train_accs = checkpoint["train_losses"], checkpoint["train_accs"] 
val_losses, val_accs = checkpoint["val_losses"], checkpoint["val_accs"]

# %% [markdown]
# ### Creating a new model

# %%
batch_size = 128
epochs = 100
prints = 71
learning_rate = 1e-5
weight_decay = 1e-4

train_dataset = AudioFeatureDataset(x_train, y_train)
val_dataset = AudioFeatureDataset(x_val, y_val)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

#model_gru = CNN_GRU()

loss_fn = nn.CrossEntropyLoss(weight=w)
optimizer = torch.optim.Adam(model_gru.parameters(), lr=learning_rate, weight_decay=weight_decay)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.7)

#trained_model, train_losses, train_accs, val_losses, val_accs = training_loop(
#    model_gru, optimizer, loss_fn, train_dataloader, val_dataloader, epochs, prints, scheduler
#)
# Out:
# Starting training
# Epoch 1/100: Train loss: 2.052, Train acc.: 0.216, Val. loss: 2.022, Val. acc.: 0.188
# Epoch 2/100: Train loss: 1.992, Train acc.: 0.262, Val. loss: 1.969, Val. acc.: 0.220
# Epoch 3/100: Train loss: 1.929, Train acc.: 0.286, Val. loss: 1.924, Val. acc.: 0.236
# Epoch 4/100: Train loss: 1.872, Train acc.: 0.304, Val. loss: 1.870, Val. acc.: 0.284
# Epoch 5/100: Train loss: 1.813, Train acc.: 0.332, Val. loss: 1.820, Val. acc.: 0.321
# Epoch 6/100: Train loss: 1.754, Train acc.: 0.357, Val. loss: 1.766, Val. acc.: 0.336
# Epoch 7/100: Train loss: 1.697, Train acc.: 0.385, Val. loss: 1.718, Val. acc.: 0.347
# Epoch 8/100: Train loss: 1.642, Train acc.: 0.412, Val. loss: 1.667, Val. acc.: 0.376
# Epoch 9/100: Train loss: 1.581, Train acc.: 0.439, Val. loss: 1.574, Val. acc.: 0.434
# Epoch 10/100: Train loss: 1.516, Train acc.: 0.471, Val. loss: 1.522, Val. acc.: 0.453
# Epoch 11/100: Train loss: 1.452, Train acc.: 0.506, Val. loss: 1.433, Val. acc.: 0.498
# Epoch 12/100: Train loss: 1.387, Train acc.: 0.532, Val. loss: 1.371, Val. acc.: 0.531
# Epoch 13/100: Train loss: 1.333, Train acc.: 0.550, Val. loss: 1.292, Val. acc.: 0.571
# Epoch 14/100: Train loss: 1.273, Train acc.: 0.571, Val. loss: 1.240, Val. acc.: 0.585
# Epoch 15/100: Train loss: 1.222, Train acc.: 0.593, Val. loss: 1.220, Val. acc.: 0.586
# Epoch 16/100: Train loss: 1.176, Train acc.: 0.614, Val. loss: 1.157, Val. acc.: 0.607
# Epoch 17/100: Train loss: 1.135, Train acc.: 0.620, Val. loss: 1.151, Val. acc.: 0.602
# Epoch 18/100: Train loss: 1.095, Train acc.: 0.635, Val. loss: 1.096, Val. acc.: 0.619
# Epoch 19/100: Train loss: 1.059, Train acc.: 0.649, Val. loss: 1.067, Val. acc.: 0.621
# Epoch 20/100: Train loss: 1.023, Train acc.: 0.660, Val. loss: 1.016, Val. acc.: 0.648
# Epoch 21/100: Train loss: 0.997, Train acc.: 0.669, Val. loss: 1.003, Val. acc.: 0.646
# Epoch 22/100: Train loss: 0.965, Train acc.: 0.682, Val. loss: 0.990, Val. acc.: 0.654
# Epoch 23/100: Train loss: 0.944, Train acc.: 0.686, Val. loss: 0.969, Val. acc.: 0.665
# Epoch 24/100: Train loss: 0.909, Train acc.: 0.702, Val. loss: 0.931, Val. acc.: 0.668
# Epoch 25/100: Train loss: 0.889, Train acc.: 0.706, Val. loss: 0.926, Val. acc.: 0.673
# Epoch 26/100: Train loss: 0.868, Train acc.: 0.714, Val. loss: 0.885, Val. acc.: 0.693
# Epoch 27/100: Train loss: 0.841, Train acc.: 0.725, Val. loss: 0.854, Val. acc.: 0.696
# Epoch 28/100: Train loss: 0.817, Train acc.: 0.730, Val. loss: 0.848, Val. acc.: 0.704
# Epoch 29/100: Train loss: 0.801, Train acc.: 0.736, Val. loss: 0.812, Val. acc.: 0.714
# Epoch 30/100: Train loss: 0.777, Train acc.: 0.741, Val. loss: 0.811, Val. acc.: 0.710
# Epoch 31/100: Train loss: 0.763, Train acc.: 0.745, Val. loss: 0.789, Val. acc.: 0.712
# Epoch 32/100: Train loss: 0.741, Train acc.: 0.755, Val. loss: 0.749, Val. acc.: 0.721
# Epoch 33/100: Train loss: 0.724, Train acc.: 0.758, Val. loss: 0.749, Val. acc.: 0.722
# Epoch 34/100: Train loss: 0.711, Train acc.: 0.758, Val. loss: 0.722, Val. acc.: 0.729
# Epoch 35/100: Train loss: 0.696, Train acc.: 0.765, Val. loss: 0.706, Val. acc.: 0.737
# Epoch 36/100: Train loss: 0.675, Train acc.: 0.771, Val. loss: 0.696, Val. acc.: 0.739
# Epoch 37/100: Train loss: 0.669, Train acc.: 0.775, Val. loss: 0.690, Val. acc.: 0.740
# Epoch 38/100: Train loss: 0.652, Train acc.: 0.782, Val. loss: 0.675, Val. acc.: 0.751
# Epoch 39/100: Train loss: 0.637, Train acc.: 0.781, Val. loss: 0.658, Val. acc.: 0.756
# Epoch 40/100: Train loss: 0.620, Train acc.: 0.792, Val. loss: 0.656, Val. acc.: 0.758
# Epoch 41/100: Train loss: 0.618, Train acc.: 0.794, Val. loss: 0.641, Val. acc.: 0.764
# Epoch 42/100: Train loss: 0.602, Train acc.: 0.799, Val. loss: 0.630, Val. acc.: 0.767
# Epoch 43/100: Train loss: 0.585, Train acc.: 0.802, Val. loss: 0.623, Val. acc.: 0.769
# Epoch 44/100: Train loss: 0.586, Train acc.: 0.804, Val. loss: 0.613, Val. acc.: 0.772
# Epoch 45/100: Train loss: 0.571, Train acc.: 0.808, Val. loss: 0.602, Val. acc.: 0.778
# Epoch 46/100: Train loss: 0.558, Train acc.: 0.813, Val. loss: 0.592, Val. acc.: 0.783
# Epoch 47/100: Train loss: 0.550, Train acc.: 0.815, Val. loss: 0.581, Val. acc.: 0.781
# Epoch 48/100: Train loss: 0.542, Train acc.: 0.819, Val. loss: 0.573, Val. acc.: 0.784
# Epoch 49/100: Train loss: 0.529, Train acc.: 0.820, Val. loss: 0.575, Val. acc.: 0.797
# Epoch 50/100: Train loss: 0.524, Train acc.: 0.825, Val. loss: 0.565, Val. acc.: 0.794
# Epoch 51/100: Train loss: 0.510, Train acc.: 0.830, Val. loss: 0.556, Val. acc.: 0.802
# Epoch 52/100: Train loss: 0.501, Train acc.: 0.832, Val. loss: 0.554, Val. acc.: 0.797
# Epoch 53/100: Train loss: 0.498, Train acc.: 0.832, Val. loss: 0.544, Val. acc.: 0.810
# Epoch 54/100: Train loss: 0.492, Train acc.: 0.835, Val. loss: 0.535, Val. acc.: 0.814
# Epoch 55/100: Train loss: 0.475, Train acc.: 0.844, Val. loss: 0.540, Val. acc.: 0.806
# Epoch 56/100: Train loss: 0.468, Train acc.: 0.842, Val. loss: 0.524, Val. acc.: 0.819
# Epoch 57/100: Train loss: 0.464, Train acc.: 0.846, Val. loss: 0.524, Val. acc.: 0.811
# Epoch 58/100: Train loss: 0.460, Train acc.: 0.846, Val. loss: 0.517, Val. acc.: 0.817
# Epoch 59/100: Train loss: 0.453, Train acc.: 0.849, Val. loss: 0.513, Val. acc.: 0.822
# Epoch 60/100: Train loss: 0.445, Train acc.: 0.851, Val. loss: 0.500, Val. acc.: 0.832
# Epoch 61/100: Train loss: 0.430, Train acc.: 0.857, Val. loss: 0.495, Val. acc.: 0.832
# Epoch 62/100: Train loss: 0.425, Train acc.: 0.858, Val. loss: 0.489, Val. acc.: 0.832
# Epoch 63/100: Train loss: 0.418, Train acc.: 0.858, Val. loss: 0.498, Val. acc.: 0.833
# Epoch 64/100: Train loss: 0.416, Train acc.: 0.858, Val. loss: 0.478, Val. acc.: 0.839
# Epoch 65/100: Train loss: 0.410, Train acc.: 0.865, Val. loss: 0.481, Val. acc.: 0.843
# Epoch 66/100: Train loss: 0.405, Train acc.: 0.864, Val. loss: 0.476, Val. acc.: 0.844
# Epoch 67/100: Train loss: 0.396, Train acc.: 0.868, Val. loss: 0.466, Val. acc.: 0.849
# Epoch 68/100: Train loss: 0.392, Train acc.: 0.867, Val. loss: 0.481, Val. acc.: 0.839
# Epoch 69/100: Train loss: 0.383, Train acc.: 0.872, Val. loss: 0.461, Val. acc.: 0.849
# Epoch 70/100: Train loss: 0.377, Train acc.: 0.874, Val. loss: 0.465, Val. acc.: 0.849
# Epoch 71/100: Train loss: 0.371, Train acc.: 0.874, Val. loss: 0.464, Val. acc.: 0.847
# Epoch 72/100: Train loss: 0.372, Train acc.: 0.872, Val. loss: 0.460, Val. acc.: 0.852
# Epoch 73/100: Train loss: 0.359, Train acc.: 0.876, Val. loss: 0.448, Val. acc.: 0.854
# Epoch 74/100: Train loss: 0.356, Train acc.: 0.879, Val. loss: 0.451, Val. acc.: 0.851
# Epoch 75/100: Train loss: 0.352, Train acc.: 0.882, Val. loss: 0.450, Val. acc.: 0.849
# Epoch 76/100: Train loss: 0.347, Train acc.: 0.881, Val. loss: 0.439, Val. acc.: 0.851
# Epoch 77/100: Train loss: 0.346, Train acc.: 0.883, Val. loss: 0.439, Val. acc.: 0.851
# Epoch 78/100: Train loss: 0.336, Train acc.: 0.888, Val. loss: 0.453, Val. acc.: 0.847
# Epoch 79/100: Train loss: 0.334, Train acc.: 0.886, Val. loss: 0.442, Val. acc.: 0.854
# Epoch 80/100: Train loss: 0.328, Train acc.: 0.887, Val. loss: 0.440, Val. acc.: 0.858
# Epoch 81/100: Train loss: 0.321, Train acc.: 0.889, Val. loss: 0.438, Val. acc.: 0.854
# Epoch 82/100: Train loss: 0.316, Train acc.: 0.889, Val. loss: 0.425, Val. acc.: 0.857
# Epoch 83/100: Train loss: 0.315, Train acc.: 0.892, Val. loss: 0.430, Val. acc.: 0.857
# Epoch 84/100: Train loss: 0.317, Train acc.: 0.892, Val. loss: 0.431, Val. acc.: 0.855
# Epoch 85/100: Train loss: 0.307, Train acc.: 0.897, Val. loss: 0.438, Val. acc.: 0.857
# Epoch 86/100: Train loss: 0.305, Train acc.: 0.895, Val. loss: 0.440, Val. acc.: 0.852
# Epoch 87/100: Train loss: 0.300, Train acc.: 0.895, Val. loss: 0.443, Val. acc.: 0.852
# Epoch 88/100: Train loss: 0.298, Train acc.: 0.897, Val. loss: 0.432, Val. acc.: 0.855
# Epoch 89/100: Train loss: 0.296, Train acc.: 0.899, Val. loss: 0.432, Val. acc.: 0.857
# Epoch 90/100: Train loss: 0.293, Train acc.: 0.896, Val. loss: 0.443, Val. acc.: 0.849
# Epoch 91/100: Train loss: 0.284, Train acc.: 0.902, Val. loss: 0.433, Val. acc.: 0.851
# Epoch 92/100: Train loss: 0.287, Train acc.: 0.902, Val. loss: 0.435, Val. acc.: 0.851
# Epoch 93/100: Train loss: 0.285, Train acc.: 0.905, Val. loss: 0.430, Val. acc.: 0.851
# Epoch 94/100: Train loss: 0.282, Train acc.: 0.903, Val. loss: 0.423, Val. acc.: 0.849
# Epoch 95/100: Train loss: 0.278, Train acc.: 0.903, Val. loss: 0.425, Val. acc.: 0.855
# Epoch 96/100: Train loss: 0.277, Train acc.: 0.904, Val. loss: 0.435, Val. acc.: 0.851
# Epoch 97/100: Train loss: 0.283, Train acc.: 0.904, Val. loss: 0.417, Val. acc.: 0.849
# Epoch 98/100: Train loss: 0.271, Train acc.: 0.908, Val. loss: 0.422, Val. acc.: 0.855
# Epoch 99/100: Train loss: 0.278, Train acc.: 0.904, Val. loss: 0.419, Val. acc.: 0.851
# Epoch 100/100: Train loss: 0.270, Train acc.: 0.908, Val. loss: 0.420, Val. acc.: 0.849

# %% [markdown]
# ### Saving CNN_GRU

# %%
# Should not be ran anymore since we got the final results
"""
torch.save(
    {
        "model_state_dict": trained_model.state_dict(),
        "train_losses": train_losses, 
        "train_accs": train_accs, 
        "val_losses": val_losses, 
        "val_accs": val_accs
    },
    "./cnn_gru_model_2d_stable.ckpt",
)
"""

# %%
plot_loss_acc(train_losses, train_accs, val_losses, val_accs, "cnn_gru_model_2d")

# %%
from collections import Counter
# %matplotlib inline

counter = Counter(emotions)

counts = {emotion: counter[emotion] for emotion in emotions}
print(counts)

emotions_list = list(counts.keys())
count_emotions = list(counts.values())

plt.bar(emotions_list, count_emotions)

plt.xlabel("Emotion")
plt.ylabel("Number of audio files")
plt.title("Number of audio files per emotion")

plt.xticks()
plt.show()
# Out:
# {'angry': 592, 'disgust': 592, 'fear': 592, 'happy': 592, 'neutral': 496, 'surprised': 592, 'sad': 592, 'calm': 192}
